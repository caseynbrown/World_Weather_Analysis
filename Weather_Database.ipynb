# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities= []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
weather_api_key= "40bf648275392d294c604d3f8f57d8ff"

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=40bf648275392d294c604d3f8f57d8ff

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | micheweni
# Processing Record 3 of Set 1 | sorong
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | coquimbo
# Processing Record 10 of Set 1 | verkhniy landekh
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | birao
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | bilma
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | taitung
# Processing Record 26 of Set 1 | bonthe
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | tari
# Processing Record 29 of Set 1 | comodoro rivadavia
# Processing Record 30 of Set 1 | wangaratta
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | havre
# Processing Record 35 of Set 1 | jacareacanga
# Processing Record 36 of Set 1 | aitape
# Processing Record 37 of Set 1 | taldan
# Processing Record 38 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | kunming
# Processing Record 41 of Set 1 | rokytne
# Processing Record 42 of Set 1 | bahia honda
# Processing Record 43 of Set 1 | sokol
# Processing Record 44 of Set 1 | ponta delgada
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | thinadhoo
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | lady frere
# Processing Record 2 of Set 2 | saint-georges
# Processing Record 3 of Set 2 | bilibino
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | teguise
# Processing Record 7 of Set 2 | hovd
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | oussouye
# Processing Record 10 of Set 2 | la rochelle
# Processing Record 11 of Set 2 | shakhrinau
# City not found. Skipping...
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | walvis bay
# Processing Record 15 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | nurota
# Processing Record 19 of Set 2 | sigli
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | sur
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | caravelas
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | umm lajj
# Processing Record 32 of Set 2 | puerto cabello
# Processing Record 33 of Set 2 | salinopolis
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | samarai
# Processing Record 37 of Set 2 | clarence town
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | merke
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | monte alegre
# Processing Record 42 of Set 2 | atar
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | boshnyakovo
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | santa cruz
# Processing Record 47 of Set 2 | tres arroyos
# Processing Record 48 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 2 | marsh harbour
# Processing Record 1 of Set 3 | hualmay
# Processing Record 2 of Set 3 | abu samrah
# Processing Record 3 of Set 3 | urusha
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | punta arenas
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | calvia
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | buncrana
# Processing Record 13 of Set 3 | sabha
# Processing Record 14 of Set 3 | karratha
# Processing Record 15 of Set 3 | kananga
# Processing Record 16 of Set 3 | ramnagar
# Processing Record 17 of Set 3 | pisco
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | sumbe
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | surat thani
# Processing Record 23 of Set 3 | mount gambier
# Processing Record 24 of Set 3 | lubbock
# Processing Record 25 of Set 3 | mariakani
# Processing Record 26 of Set 3 | nyagan
# Processing Record 27 of Set 3 | sovetskiy
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | belyy yar
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | goundam
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | boralday
# Processing Record 34 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 3 | talas
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | lodja
# Processing Record 38 of Set 3 | tottori
# Processing Record 39 of Set 3 | bireun
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | bitkine
# Processing Record 42 of Set 3 | richmond
# Processing Record 43 of Set 3 | nuuk
# Processing Record 44 of Set 3 | francisco sa
# Processing Record 45 of Set 3 | winnemucca
# Processing Record 46 of Set 3 | nong khae
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | poitiers
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | ostersund
# Processing Record 2 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 4 | mogadishu
# Processing Record 4 of Set 4 | bjerkvik
# Processing Record 5 of Set 4 | longyearbyen
# Processing Record 6 of Set 4 | buluang
# Processing Record 7 of Set 4 | biak
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | crestview
# Processing Record 10 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 4 | formosa
# Processing Record 13 of Set 4 | san luis
# Processing Record 14 of Set 4 | dalby
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | abu kamal
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | chuy
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | maragogi
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | khandyga
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | egvekinot
# Processing Record 28 of Set 4 | goderich
# Processing Record 29 of Set 4 | manicore
# Processing Record 30 of Set 4 | weiser
# Processing Record 31 of Set 4 | saint-pierre
# Processing Record 32 of Set 4 | kosa
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | naze
# Processing Record 35 of Set 4 | sao felix do xingu
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | warrington
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | gualeguaychu
# Processing Record 40 of Set 4 | catamarca
# Processing Record 41 of Set 4 | xapuri
# Processing Record 42 of Set 4 | ozernovskiy
# Processing Record 43 of Set 4 | gisborne
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | novyy yarychiv
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | kizhinga
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | talara
# Processing Record 1 of Set 5 | olafsvik
# Processing Record 2 of Set 5 | castle rock
# Processing Record 3 of Set 5 | qaqortoq
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | baruun-urt
# Processing Record 6 of Set 5 | kruisfontein
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | tambovka
# Processing Record 9 of Set 5 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | biloela
# Processing Record 13 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 5 | campbell river
# Processing Record 15 of Set 5 | qaanaaq
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | necochea
# Processing Record 19 of Set 5 | turka
# Processing Record 20 of Set 5 | kapaa
# Processing Record 21 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 5 | skibbereen
# Processing Record 23 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 5 | coihaique
# Processing Record 25 of Set 5 | muravlenko
# Processing Record 26 of Set 5 | viedma
# Processing Record 27 of Set 5 | kailua
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | christchurch
# Processing Record 30 of Set 5 | scarborough
# Processing Record 31 of Set 5 | houma
# Processing Record 32 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | ahuimanu
# Processing Record 35 of Set 5 | tual
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | manokwari
# Processing Record 41 of Set 5 | acapulco
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | paamiut
# Processing Record 45 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | punta de bombon
# Processing Record 48 of Set 5 | jalesar
# Processing Record 49 of Set 5 | ewa beach
# Processing Record 50 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 6 | kununurra
# Processing Record 2 of Set 6 | la brea
# Processing Record 3 of Set 6 | selizharovo
# Processing Record 4 of Set 6 | contai
# Processing Record 5 of Set 6 | aksarka
# Processing Record 6 of Set 6 | birjand
# Processing Record 7 of Set 6 | amarillo
# Processing Record 8 of Set 6 | jertih
# Processing Record 9 of Set 6 | north myrtle beach
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 6 | puerto penasco
# Processing Record 13 of Set 6 | acajutla
# Processing Record 14 of Set 6 | waw
# Processing Record 15 of Set 6 | makat
# Processing Record 16 of Set 6 | xai-xai
# Processing Record 17 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | oswego
# Processing Record 20 of Set 6 | along
# Processing Record 21 of Set 6 | kamwenge
# Processing Record 22 of Set 6 | georgetown
# Processing Record 23 of Set 6 | sao joao da barra
# Processing Record 24 of Set 6 | nalut
# Processing Record 25 of Set 6 | thanh hoa
# Processing Record 26 of Set 6 | flin flon
# Processing Record 27 of Set 6 | shimoda
# Processing Record 28 of Set 6 | ketchikan
# Processing Record 29 of Set 6 | fairbanks
# Processing Record 30 of Set 6 | gat
# Processing Record 31 of Set 6 | gazimurskiy zavod
# Processing Record 32 of Set 6 | aripuana
# Processing Record 33 of Set 6 | general pico
# Processing Record 34 of Set 6 | hirara
# Processing Record 35 of Set 6 | brownwood
# Processing Record 36 of Set 6 | teeli
# Processing Record 37 of Set 6 | gold coast
# Processing Record 38 of Set 6 | kumluca
# Processing Record 39 of Set 6 | ostrovnoy
# Processing Record 40 of Set 6 | avarua
# Processing Record 41 of Set 6 | saucillo
# Processing Record 42 of Set 6 | makakilo city
# Processing Record 43 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 6 | estelle
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | outlook
# Processing Record 47 of Set 6 | yulara
# Processing Record 48 of Set 6 | kon tum
# Processing Record 49 of Set 6 | bud
# Processing Record 50 of Set 6 | cabo san lucas
# Processing Record 1 of Set 7 | pacific grove
# Processing Record 2 of Set 7 | sisimiut
# Processing Record 3 of Set 7 | sechura
# Processing Record 4 of Set 7 | emerald
# Processing Record 5 of Set 7 | gwadar
# Processing Record 6 of Set 7 | safranbolu
# Processing Record 7 of Set 7 | margate
# Processing Record 8 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 7 | chateaurenard
# Processing Record 10 of Set 7 | tucumcari
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 7 | ribas do rio pardo
# Processing Record 15 of Set 7 | barao de melgaco
# Processing Record 16 of Set 7 | mongu
# Processing Record 17 of Set 7 | canandaigua
# Processing Record 18 of Set 7 | tazovskiy
# Processing Record 19 of Set 7 | taltal
# Processing Record 20 of Set 7 | acarau
# Processing Record 21 of Set 7 | longkou
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | faya
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | rancho palos verdes
# Processing Record 26 of Set 7 | mahon
# Processing Record 27 of Set 7 | kjollefjord
# Processing Record 28 of Set 7 | gohpur
# Processing Record 29 of Set 7 | sikonge
# Processing Record 30 of Set 7 | batagay-alyta
# Processing Record 31 of Set 7 | huntsville
# Processing Record 32 of Set 7 | filingue
# Processing Record 33 of Set 7 | trinidad
# Processing Record 34 of Set 7 | nybro
# Processing Record 35 of Set 7 | camacari
# Processing Record 36 of Set 7 | yar-sale
# Processing Record 37 of Set 7 | rio gallegos
# Processing Record 38 of Set 7 | plaster rock
# Processing Record 39 of Set 7 | marche-en-famenne
# Processing Record 40 of Set 7 | pozo colorado
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 44 of Set 7 | puerto baquerizo moreno
# Processing Record 45 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 7 | znamenskoye
# Processing Record 47 of Set 7 | sao filipe
# Processing Record 48 of Set 7 | motril
# Processing Record 49 of Set 7 | buraydah
# Processing Record 50 of Set 7 | burica
# City not found. Skipping...
# Processing Record 1 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | ginir
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | high level
# Processing Record 6 of Set 8 | kuytun
# Processing Record 7 of Set 8 | severo-kurilsk
# Processing Record 8 of Set 8 | dakar
# Processing Record 9 of Set 8 | sambava
# Processing Record 10 of Set 8 | bom jesus
# Processing Record 11 of Set 8 | panzhihua
# Processing Record 12 of Set 8 | balezino
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 8 | ewing
# Processing Record 16 of Set 8 | ust-kuyga
# Processing Record 17 of Set 8 | jinan
# Processing Record 18 of Set 8 | uvinza
# Processing Record 19 of Set 8 | musoma
# Processing Record 20 of Set 8 | camabatela
# Processing Record 21 of Set 8 | tiznit
# Processing Record 22 of Set 8 | smithers
# Processing Record 23 of Set 8 | srednekolymsk
# Processing Record 24 of Set 8 | ponta do sol
# Processing Record 25 of Set 8 | jiuquan
# Processing Record 26 of Set 8 | bose
# Processing Record 27 of Set 8 | calama
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | altona
# Processing Record 31 of Set 8 | touros
# Processing Record 32 of Set 8 | thaba nchu
# Processing Record 33 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 8 | gospic
# Processing Record 35 of Set 8 | venado tuerto
# Processing Record 36 of Set 8 | sao raimundo nonato
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | raudeberg
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | sassandra
# Processing Record 41 of Set 8 | yatou
# Processing Record 42 of Set 8 | prince rupert
# Processing Record 43 of Set 8 | gashua
# Processing Record 44 of Set 8 | cravo norte
# Processing Record 45 of Set 8 | mushie
# Processing Record 46 of Set 8 | port hedland
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | fort nelson
# Processing Record 49 of Set 8 | pyshchug
# Processing Record 50 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | balykshi
# Processing Record 2 of Set 9 | waingapu
# Processing Record 3 of Set 9 | koindu
# Processing Record 4 of Set 9 | kaniama
# Processing Record 5 of Set 9 | general roca
# Processing Record 6 of Set 9 | puerto escondido
# Processing Record 7 of Set 9 | abha
# Processing Record 8 of Set 9 | marau
# Processing Record 9 of Set 9 | tateyama
# Processing Record 10 of Set 9 | sioux lookout
# Processing Record 11 of Set 9 | pundaguitan
# Processing Record 12 of Set 9 | padang
# Processing Record 13 of Set 9 | dawei
# Processing Record 14 of Set 9 | bairnsdale
# Processing Record 15 of Set 9 | alto araguaia
# Processing Record 16 of Set 9 | zarubino
# Processing Record 17 of Set 9 | bowen
# Processing Record 18 of Set 9 | paripiranga
# Processing Record 19 of Set 9 | vestmanna
# Processing Record 20 of Set 9 | americus
# Processing Record 21 of Set 9 | amahai
# Processing Record 22 of Set 9 | san juan de uraba
# Processing Record 23 of Set 9 | sivas
# Processing Record 24 of Set 9 | meulaboh
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | beringovskiy
# Processing Record 27 of Set 9 | wainwright
# Processing Record 28 of Set 9 | the pas
# Processing Record 29 of Set 9 | jos
# Processing Record 30 of Set 9 | urumqi
# Processing Record 31 of Set 9 | serik
# Processing Record 32 of Set 9 | la rioja
# Processing Record 33 of Set 9 | half moon bay
# Processing Record 34 of Set 9 | haines junction
# Processing Record 35 of Set 9 | broken hill
# Processing Record 36 of Set 9 | okhotsk
# Processing Record 37 of Set 9 | rosehearty
# Processing Record 38 of Set 9 | san felipe
# Processing Record 39 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 9 | dunedin
# Processing Record 41 of Set 9 | mzimba
# Processing Record 42 of Set 9 | portland
# Processing Record 43 of Set 9 | gazojak
# Processing Record 44 of Set 9 | keti bandar
# Processing Record 45 of Set 9 | kupang
# Processing Record 46 of Set 9 | vardo
# Processing Record 47 of Set 9 | tiruppur
# Processing Record 48 of Set 9 | moorhead
# Processing Record 49 of Set 9 | mirnyy
# Processing Record 50 of Set 9 | reshetylivka
# Processing Record 1 of Set 10 | zdvinsk
# Processing Record 2 of Set 10 | pelym
# Processing Record 3 of Set 10 | balaipungut
# Processing Record 4 of Set 10 | shingu
# Processing Record 5 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 10 | tarumovka
# Processing Record 7 of Set 10 | kalevala
# Processing Record 8 of Set 10 | puro
# Processing Record 9 of Set 10 | mehriz
# Processing Record 10 of Set 10 | talnakh
# Processing Record 11 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 10 | malinovskiy
# Processing Record 13 of Set 10 | pevek
# Processing Record 14 of Set 10 | moussoro
# Processing Record 15 of Set 10 | hami
# Processing Record 16 of Set 10 | nadym
# Processing Record 17 of Set 10 | arroyo
# Processing Record 18 of Set 10 | jieshi
# Processing Record 19 of Set 10 | tabas
# Processing Record 20 of Set 10 | umm kaddadah
# Processing Record 21 of Set 10 | sabang
# Processing Record 22 of Set 10 | nicoya
# Processing Record 23 of Set 10 | dobryanka
# Processing Record 24 of Set 10 | khani
# Processing Record 25 of Set 10 | vila
# Processing Record 26 of Set 10 | hermagor
# Processing Record 27 of Set 10 | ust-nera
# Processing Record 28 of Set 10 | pangnirtung
# Processing Record 29 of Set 10 | quatre cocos
# Processing Record 30 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 31 of Set 10 | amudat
# Processing Record 32 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 10 | hayden
# Processing Record 34 of Set 10 | hazorasp
# Processing Record 35 of Set 10 | hobyo
# Processing Record 36 of Set 10 | posse
# Processing Record 37 of Set 10 | durant
# Processing Record 38 of Set 10 | canto do buriti
# Processing Record 39 of Set 10 | ust-tsilma
# Processing Record 40 of Set 10 | haukipudas
# Processing Record 41 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 10 | gushikawa
# Processing Record 43 of Set 10 | turangi
# Processing Record 44 of Set 10 | mapiripan
# Processing Record 45 of Set 10 | axim
# Processing Record 46 of Set 10 | sorland
# Processing Record 47 of Set 10 | long beach
# Processing Record 48 of Set 10 | dali
# Processing Record 49 of Set 10 | sobolevo
# Processing Record 50 of Set 10 | santa rosa
# Processing Record 1 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 11 | anaimalai
# Processing Record 3 of Set 11 | isabela
# Processing Record 4 of Set 11 | ulladulla
# Processing Record 5 of Set 11 | burns lake
# Processing Record 6 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 11 | guangshui
# Processing Record 8 of Set 11 | corning
# Processing Record 9 of Set 11 | vanimo
# Processing Record 10 of Set 11 | adra
# Processing Record 11 of Set 11 | lucapa
# Processing Record 12 of Set 11 | batagay
# Processing Record 13 of Set 11 | dunda
# Processing Record 14 of Set 11 | anshun
# Processing Record 15 of Set 11 | coolum beach
# Processing Record 16 of Set 11 | upernavik
# Processing Record 17 of Set 11 | beyneu
# Processing Record 18 of Set 11 | jalu
# Processing Record 19 of Set 11 | coahuayana
# Processing Record 20 of Set 11 | savannah bight
# Processing Record 21 of Set 11 | ayan
# Processing Record 22 of Set 11 | toora-khem
# Processing Record 23 of Set 11 | grindavik
# Processing Record 24 of Set 11 | balabac
# Processing Record 25 of Set 11 | elizabeth city
# Processing Record 26 of Set 11 | san jeronimo
# Processing Record 27 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 11 | sohbatpur
# Processing Record 29 of Set 11 | denizli
# Processing Record 30 of Set 11 | davydovka
# Processing Record 31 of Set 11 | mackay
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 11 | linhares
# Processing Record 35 of Set 11 | yaan
# Processing Record 36 of Set 11 | belo oriente
# Processing Record 37 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 11 | kamaishi
# Processing Record 39 of Set 11 | damghan
# Processing Record 40 of Set 11 | bay roberts
# Processing Record 41 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 11 | chepareria
# Processing Record 43 of Set 11 | milkovo
# Processing Record 44 of Set 11 | kaabong
# Processing Record 45 of Set 11 | kontagora
# Processing Record 46 of Set 11 | marsabit
# Processing Record 47 of Set 11 | parkersburg
# Processing Record 48 of Set 11 | flinders
# Processing Record 49 of Set 11 | carutapera
# Processing Record 50 of Set 11 | gao
# Processing Record 1 of Set 12 | san lazaro
# Processing Record 2 of Set 12 | saldanha
# Processing Record 3 of Set 12 | semporna
# Processing Record 4 of Set 12 | katsuura
# Processing Record 5 of Set 12 | jutai
# Processing Record 6 of Set 12 | carupano
# Processing Record 7 of Set 12 | oriximina
# Processing Record 8 of Set 12 | mayumba
# Processing Record 9 of Set 12 | yagodnoye
# Processing Record 10 of Set 12 | gizo
# Processing Record 11 of Set 12 | kluczbork
# Processing Record 12 of Set 12 | farah
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | meridian
# Processing Record 15 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 16 of Set 12 | trelew
# Processing Record 17 of Set 12 | namibe
# Processing Record 18 of Set 12 | eirunepe
# Processing Record 19 of Set 12 | arlit
# Processing Record 20 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 21 of Set 12 | granada
# Processing Record 22 of Set 12 | farrukhnagar
# Processing Record 23 of Set 12 | igrim
# Processing Record 24 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 12 | lyantonde
# Processing Record 26 of Set 12 | strezhevoy
# Processing Record 27 of Set 12 | alofi
# Processing Record 28 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 12 | westport
# Processing Record 30 of Set 12 | aldan
# Processing Record 31 of Set 12 | kalmunai
# Processing Record 32 of Set 12 | maridi
# Processing Record 33 of Set 12 | middelburg
# Processing Record 34 of Set 12 | tharad
# Processing Record 35 of Set 12 | ahipara
# Processing Record 36 of Set 12 | graaff-reinet
# Processing Record 37 of Set 12 | gambela
# Processing Record 38 of Set 12 | cap malheureux
# Processing Record 39 of Set 12 | namatanai
# Processing Record 40 of Set 12 | mao
# Processing Record 41 of Set 12 | hirado
# Processing Record 42 of Set 12 | sokoto
# Processing Record 43 of Set 12 | le port
# Processing Record 44 of Set 12 | russkiy kameshkir
# Processing Record 45 of Set 12 | dobsice
# Processing Record 46 of Set 12 | grand gaube
# Processing Record 47 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 12 | arcabuco
# Processing Record 49 of Set 12 | san quintin
# Processing Record 50 of Set 12 | sarkikaraagac
# Processing Record 1 of Set 13 | bon air
# Processing Record 2 of Set 13 | tilichiki
# Processing Record 3 of Set 13 | martapura
# Processing Record 4 of Set 13 | francisco beltrao
# Processing Record 5 of Set 13 | constantine
# Processing Record 6 of Set 13 | tres picos
# Processing Record 7 of Set 13 | ozerne
# Processing Record 8 of Set 13 | kurumkan
# Processing Record 9 of Set 13 | alice springs
# Processing Record 10 of Set 13 | sola
# Processing Record 11 of Set 13 | anadyr
# Processing Record 12 of Set 13 | xunchang
# Processing Record 13 of Set 13 | laguna de perlas
# Processing Record 14 of Set 13 | diamantino
# Processing Record 15 of Set 13 | guliston
# Processing Record 16 of Set 13 | prince albert
# Processing Record 17 of Set 13 | saint-paul
# Processing Record 18 of Set 13 | hoquiam
# Processing Record 19 of Set 13 | kieta
# Processing Record 20 of Set 13 | kandrian
# Processing Record 21 of Set 13 | uray
# Processing Record 22 of Set 13 | huambo
# Processing Record 23 of Set 13 | poum
# Processing Record 24 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | damaturu
# Processing Record 27 of Set 13 | svelgen
# Processing Record 28 of Set 13 | zakamensk
# Processing Record 29 of Set 13 | teknaf
# Processing Record 30 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 13 | tawang
# Processing Record 33 of Set 13 | tubuala
# Processing Record 34 of Set 13 | nikolayevskaya
# Processing Record 35 of Set 13 | ugoofaaru
# Processing Record 36 of Set 13 | ambon
# Processing Record 37 of Set 13 | kemijarvi
# Processing Record 38 of Set 13 | doha
# Processing Record 39 of Set 13 | valdivia
# Processing Record 40 of Set 13 | hervey bay
# Processing Record 41 of Set 13 | sturgeon falls
# Processing Record 42 of Set 13 | sabzevar
# Processing Record 43 of Set 13 | camalu
# Processing Record 44 of Set 13 | central point
# Processing Record 45 of Set 13 | cidreira
# Processing Record 46 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 13 | kisanga
# Processing Record 48 of Set 13 | jardim
# Processing Record 49 of Set 13 | mendi
# Processing Record 50 of Set 13 | kodinsk
# Processing Record 1 of Set 14 | colares
# Processing Record 2 of Set 14 | constitucion
# Processing Record 3 of Set 14 | bohodukhiv
# Processing Record 4 of Set 14 | joshimath
# Processing Record 5 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 14 | verkhoturye
# Processing Record 7 of Set 14 | maneadero
# Processing Record 8 of Set 14 | mount isa
# Processing Record 9 of Set 14 | awbari
# Processing Record 10 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 14 | wanning
# Processing Record 12 of Set 14 | guadalupe y calvo
# Processing Record 13 of Set 14 | xinzhi
# Processing Record 14 of Set 14 | tiebissou
# Processing Record 15 of Set 14 | mashhad
# Processing Record 16 of Set 14 | inta
# Processing Record 17 of Set 14 | duzce
# Processing Record 18 of Set 14 | sturgis
# Processing Record 19 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 14 | malanje
# Processing Record 21 of Set 14 | morant bay
# Processing Record 22 of Set 14 | mecca
# Processing Record 23 of Set 14 | kyzyl
# Processing Record 24 of Set 14 | nguru
# Processing Record 25 of Set 14 | pashkovskiy
# Processing Record 26 of Set 14 | baoding
# Processing Record 27 of Set 14 | orange cove
# Processing Record 28 of Set 14 | sarh
# Processing Record 29 of Set 14 | islamkot
# Processing Record 30 of Set 14 | riyadh
# Processing Record 31 of Set 14 | robertsport
# Processing Record 32 of Set 14 | lishan
# Processing Record 33 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 14 | dongsheng
# Processing Record 35 of Set 14 | ajdabiya
# Processing Record 36 of Set 14 | alta
# Processing Record 37 of Set 14 | benghazi
# Processing Record 38 of Set 14 | boende
# Processing Record 39 of Set 14 | avera
# Processing Record 40 of Set 14 | muros
# Processing Record 41 of Set 14 | togur
# Processing Record 42 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | khuzhir
# Processing Record 44 of Set 14 | katangli
# Processing Record 45 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | kamenka
# Processing Record 47 of Set 14 | otjimbingwe
# Processing Record 48 of Set 14 | camacha
# Processing Record 49 of Set 14 | malayal
# Processing Record 50 of Set 14 | yima
# Processing Record 1 of Set 15 | port lincoln
# Processing Record 2 of Set 15 | harper
# Processing Record 3 of Set 15 | itarema
# Processing Record 4 of Set 15 | merrill
# Processing Record 5 of Set 15 | obzor
# Processing Record 6 of Set 15 | altamont
# Processing Record 7 of Set 15 | kokkola
# Processing Record 8 of Set 15 | banjar
# Processing Record 9 of Set 15 | oksfjord
# Processing Record 10 of Set 15 | maniitsoq
# Processing Record 11 of Set 15 | kijang
# Processing Record 12 of Set 15 | ullapool
# Processing Record 13 of Set 15 | adamovka
# Processing Record 14 of Set 15 | sri aman
# Processing Record 15 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 15 | yenagoa
# Processing Record 17 of Set 15 | aykhal
# Processing Record 18 of Set 15 | vetluzhskiy
# Processing Record 19 of Set 15 | idenao
# Processing Record 20 of Set 15 | winkler
# Processing Record 21 of Set 15 | sept-iles
# Processing Record 22 of Set 15 | xining
# Processing Record 23 of Set 15 | paoua
# Processing Record 24 of Set 15 | syracuse
# Processing Record 25 of Set 15 | north bend
# Processing Record 26 of Set 15 | oistins
# Processing Record 27 of Set 15 | xichang
# Processing Record 28 of Set 15 | kushima
# Processing Record 29 of Set 15 | koungou
# Processing Record 30 of Set 15 | bodden town
# Processing Record 31 of Set 15 | ossora
# Processing Record 32 of Set 15 | red bank
# Processing Record 33 of Set 15 | isangel
# Processing Record 34 of Set 15 | aquiraz
# Processing Record 35 of Set 15 | yelizovo
# Processing Record 36 of Set 15 | varhaug
# Processing Record 37 of Set 15 | asfi
# Processing Record 38 of Set 15 | broome
# Processing Record 39 of Set 15 | praia
# Processing Record 40 of Set 15 | pedras de fogo
# Processing Record 41 of Set 15 | asau
# Processing Record 42 of Set 15 | brooks
# Processing Record 43 of Set 15 | rio grande
# Processing Record 44 of Set 15 | glenwood springs
# Processing Record 45 of Set 15 | krasnoarmeysk
# Processing Record 46 of Set 15 | dalbandin
# Processing Record 47 of Set 15 | huaihua
# Processing Record 48 of Set 15 | port keats
# Processing Record 49 of Set 15 | chico
# Processing Record 50 of Set 15 | tura
# Processing Record 1 of Set 16 | flagstaff
# Processing Record 2 of Set 16 | taoudenni
# Processing Record 3 of Set 16 | alekseyevka
# Processing Record 4 of Set 16 | altamira
# Processing Record 5 of Set 16 | yacuiba
# Processing Record 6 of Set 16 | wegorzewo
# Processing Record 7 of Set 16 | mareeba
# Processing Record 8 of Set 16 | riviere-au-renard
# Processing Record 9 of Set 16 | vila do maio
# Processing Record 10 of Set 16 | muisne
# Processing Record 11 of Set 16 | qurayyat
# Processing Record 12 of Set 16 | westerland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Micheweni  -4.9667   39.8333     78.15        84          25
# 1            Sorong  -0.8833  131.2500     80.04        82         100
# 2        Kaitangata -46.2817  169.8464     58.84        68         100
# 3           Ushuaia -54.8000  -68.3000     62.26        34          40
# 4              Hilo  19.7297 -155.0900     80.62        94         100
# 5           Fortuna  40.5982 -124.1573     51.66        79          87
# 6          Coquimbo -29.9533  -71.3436     60.53        88          75
# 7  Verkhniy Landekh  56.8389   42.5994      8.76        94          76
# 8        Nikolskoye  59.7035   30.7861     26.49        96          93
# 9       Tuktoyaktuk  69.4541 -133.0374    -11.29        99          79
#
#    Wind Speed Country Current Description                 Date
# 0        8.37      TZ          light rain  2022-11-28 23:11:57
# 1        0.31      ID     overcast clouds  2022-11-28 23:11:58
# 2        6.38      NZ     overcast clouds  2022-11-28 23:11:59
# 3       12.66      AR    scattered clouds  2022-11-28 23:11:35
# 4       11.99      US          light rain  2022-11-28 23:11:59
# 5        5.99      US     overcast clouds  2022-11-28 23:08:44
# 6        9.22      CL       broken clouds  2022-11-28 23:11:59
# 7        4.27      RU       broken clouds  2022-11-28 23:12:00
# 8        4.50      RU     overcast clouds  2022-11-28 23:12:00
# 9        9.84      CA       broken clouds  2022-11-28 23:12:01

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Micheweni      TZ  -4.9667   39.8333     78.15        84
# 1               Sorong      ID  -0.8833  131.2500     80.04        82
# 2           Kaitangata      NZ -46.2817  169.8464     58.84        68
# 3              Ushuaia      AR -54.8000  -68.3000     62.26        34
# 4                 Hilo      US  19.7297 -155.0900     80.62        94
# ..                 ...     ...      ...       ...       ...       ...
# 691  Riviere-Au-Renard      CA  48.9957  -64.3971     30.49        75
# 692       Vila Do Maio      CV  15.1333  -23.2167     74.19        65
# 693             Muisne      EC   0.6000  -80.0333     74.75        84
# 694           Qurayyat      SA  31.3318   37.3428     57.38        72
# 695         Westerland      DE  54.9079    8.3033     40.01       100
#
#      Cloudiness  Wind Speed Current Description                 Date
# 0            25        8.37          light rain  2022-11-28 23:11:57
# 1           100        0.31     overcast clouds  2022-11-28 23:11:58
# 2           100        6.38     overcast clouds  2022-11-28 23:11:59
# 3            40       12.66    scattered clouds  2022-11-28 23:11:35
# 4           100       11.99          light rain  2022-11-28 23:11:59
# ..          ...         ...                 ...                  ...
# 691          99       22.59     overcast clouds  2022-11-28 23:31:37
# 692          90       17.18     overcast clouds  2022-11-28 23:31:37
# 693         100       12.35     overcast clouds  2022-11-28 23:28:39
# 694          40        0.00    scattered clouds  2022-11-28 23:31:37
# 695         100       12.66          light rain  2022-11-28 23:31:38
#
# [696 rows x 10 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
result= city_data_df.dtypes
print(result)
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Date                    object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "C:\\Users\\casey\\OneDrive\\Desktop\\Course Work\\World Weather Analysis\\Weather_Database\\WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
